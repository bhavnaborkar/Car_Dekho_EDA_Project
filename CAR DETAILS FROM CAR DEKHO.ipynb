# %% [markdown]
# # EDA of Data From CarDekho.com

# %% [markdown]
# This dataset contains information about used cars listed on www.cardekho.com
#
# The columns in the given dataset are as follows:
#
# name
#
# year
#
# selling_price
#
# km_driven
#
# fuel
#
# seller_type
#
# transmission
#
# Owner

# %%
#importing Required library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing plotly Library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv(r"CAR DETAILS FROM CAR DEKHO.csv") #dataset

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.isnull().sum() #missig data in columns
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df['Age'] = 2025 - df['year']
df.drop('year',axis=1,inplace = True)

# %%
df.head()
# Out:
#                        name  selling_price  km_driven    fuel seller_type  \
# 0             Maruti 800 AC          60000      70000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
# 3    Datsun RediGO T Option         250000      46000  Petrol  Individual
# 4     Honda Amaze VX i-DTEC         450000     141000  Diesel  Individual
#
#   transmission         owner  Age
# 0       Manual   First Owner   18
# 1       Manual   First Owner   18
# 2       Manual   First Owner   13
# 3       Manual   First Owner    8
# 4       Manual  Second Owner   11

# %%
#pd.set_option("display.max_rows", None, "display.max_columns",None)
#df

# %%
df.describe()
# Out:
#        selling_price      km_driven          Age
# count   4.340000e+03    4340.000000  4340.000000
# mean    5.041273e+05   66215.777419    11.909217
# std     5.785487e+05   46644.102194     4.215344
# min     2.000000e+04       1.000000     5.000000
# 25%     2.087498e+05   35000.000000     9.000000
# 50%     3.500000e+05   60000.000000    11.000000
# 75%     6.000000e+05   90000.000000    14.000000
# max     8.900000e+06  806599.000000    33.000000

# %%
cat_cols = ['fuel','seller_type','transmission','owner']
i=0
while i < 4:
    fig = plt.figure(figsize=[20,5])   
    
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1  
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1
    
    plt.show()

# %% [markdown]
# 1. Number of petrol car & Disel car almost equal
# 2. CNG LPG & Electric Car have very few listing
# 3. Most of the listing are by Individual then followed by dealer
# 4. listing of manual cars are very high as compared to automatic
# 5. listing of first owner car is high then follwed by second owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   selling_price  4340 non-null   int64
#  2   km_driven      4340 non-null   int64
#  3   fuel           4340 non-null   object
#  4   seller_type    4340 non-null   object
#  5   transmission   4340 non-null   object
#  6   owner          4340 non-null   object
#  7   Age            4340 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
num_cols = ['selling_price','km_driven','Age','selling_price']
i=0
while i < 4:
    fig = plt.figure(figsize=[13,3])
    
    plt.subplot(1,2,1)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    
    
    plt.subplot(1,2,2)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    
    plt.show()

# %% [markdown]
# Dataset has lots of outliers

# %%
df['selling_price'].quantile(0.99)
# Out:
# 3200000.0

# %% [markdown]
# # Outliers in selling price

# %%
df[df['selling_price'] > df['selling_price'].quantile(0.99)].sort_values(by="selling_price",ascending=False)
# Out:
#                                                    name  selling_price  \
# 3872           Audi RS7 2015-2019 Sportback Performance        8900000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition        8150000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC        5500000
# 612                             BMW X5 xDrive 30d xLine        4950000
# 1836                            BMW X5 xDrive 30d xLine        4950000
# 2258                            BMW X5 xDrive 30d xLine        4950000
# 1023                            BMW X5 xDrive 30d xLine        4950000
# 2739                            BMW X5 xDrive 30d xLine        4950000
# 919                             BMW X5 xDrive 30d xLine        4950000
# 2239                            BMW X5 xDrive 30d xLine        4950000
# 900                             BMW X5 xDrive 30d xLine        4950000
# 593                             BMW X5 xDrive 30d xLine        4950000
# 574                             BMW X5 xDrive 30d xLine        4950000
# 555                             BMW X5 xDrive 30d xLine        4950000
# 3453                      BMW 5 Series 520d Luxury Line        4800000
# 3883                      BMW 5 Series 520d Luxury Line        4800000
# 963                                   Audi A5 Sportback        4700000
# 101          Mercedes-Benz E-Class Exclusive E 200 BSIV        4500000
# 2580         Mercedes-Benz E-Class Exclusive E 200 BSIV        4500000
# 4047                    Volvo XC 90 D5 Inscription BSIV        4500000
# 539      Mercedes-Benz GL-Class 350 CDI Blue Efficiency        4400000
# 2178     Mercedes-Benz GL-Class 350 CDI Blue Efficiency        4400000
# 3875     Land Rover Range Rover 4.4 Diesel LWB Vogue SE        4200000
# 731               Land Rover Discovery Sport TD4 HSE 7S        4000000
# 968                        BMW 7 Series Signature 730Ld        4000000
# 988                      Land Rover Discovery S 2.0 SD4        4000000
# 2295                 Audi Q5 3.0 TDI Quattro Technology        3899000
# 4304                 Audi Q5 3.0 TDI Quattro Technology        3899000
# 2237           Mercedes-Benz C-Class Progressive C 220d        3800000
# 2256           Mercedes-Benz C-Class Progressive C 220d        3800000
# 1834           Mercedes-Benz C-Class Progressive C 220d        3800000
# 2737           Mercedes-Benz C-Class Progressive C 220d        3800000
# 1021           Mercedes-Benz C-Class Progressive C 220d        3800000
# 917            Mercedes-Benz C-Class Progressive C 220d        3800000
# 898            Mercedes-Benz C-Class Progressive C 220d        3800000
# 610            Mercedes-Benz C-Class Progressive C 220d        3800000
# 591            Mercedes-Benz C-Class Progressive C 220d        3800000
# 572            Mercedes-Benz C-Class Progressive C 220d        3800000
# 553            Mercedes-Benz C-Class Progressive C 220d        3800000
# 1705                                    Audi Q5 2.0 TDI        3500000
# 1088          Land Rover Discovery Sport SD4 HSE Luxury        3500000
# 1479                        Audi A4 35 TDI Premium Plus        3256000
#
#       km_driven    fuel seller_type transmission         owner  Age
# 3872      13000  Petrol      Dealer    Automatic   First Owner    9
# 89         6500  Diesel      Dealer    Automatic   First Owner    8
# 3969      77350  Diesel      Dealer    Automatic   First Owner    9
# 612       30000  Diesel      Dealer    Automatic   First Owner    6
# 1836      30000  Diesel      Dealer    Automatic   First Owner    6
# 2258      30000  Diesel      Dealer    Automatic   First Owner    6
# 1023      30000  Diesel      Dealer    Automatic   First Owner    6
# 2739      30000  Diesel      Dealer    Automatic   First Owner    6
# 919       30000  Diesel      Dealer    Automatic   First Owner    6
# 2239      30000  Diesel      Dealer    Automatic   First Owner    6
# 900       30000  Diesel      Dealer    Automatic   First Owner    6
# 593       30000  Diesel      Dealer    Automatic   First Owner    6
# 574       30000  Diesel      Dealer    Automatic   First Owner    6
# 555       30000  Diesel      Dealer    Automatic   First Owner    6
# 3453       9422  Diesel  Individual    Automatic   First Owner    7
# 3883      12999  Diesel      Dealer    Automatic   First Owner    6
# 963        1500  Diesel  Individual    Automatic   First Owner    5
# 101        9800  Petrol      Dealer    Automatic   First Owner    7
# 2580       9800  Petrol      Dealer    Automatic   First Owner    7
# 4047      80000  Diesel  Individual    Automatic   First Owner    8
# 539      100000  Diesel  Individual    Automatic  Second Owner   11
# 2178     100000  Diesel  Individual    Automatic  Second Owner   11
# 3875     100000  Diesel      Dealer    Automatic   First Owner   15
# 731       68000  Diesel  Individual    Automatic   First Owner    7
# 968       47000  Diesel  Individual    Automatic   First Owner   11
# 988       68000  Petrol  Individual    Automatic   First Owner    7
# 2295      22000  Diesel      Dealer    Automatic   First Owner    7
# 4304      22000  Diesel      Dealer    Automatic   First Owner    7
# 2237      10000  Diesel      Dealer    Automatic   First Owner    7
# 2256      10000  Diesel      Dealer    Automatic   First Owner    7
# 1834      10000  Diesel      Dealer    Automatic   First Owner    7
# 2737      10000  Diesel      Dealer    Automatic   First Owner    7
# 1021      10000  Diesel      Dealer    Automatic   First Owner    7
# 917       10000  Diesel      Dealer    Automatic   First Owner    7
# 898       10000  Diesel      Dealer    Automatic   First Owner    7
# 610       10000  Diesel      Dealer    Automatic   First Owner    7
# 591       10000  Diesel      Dealer    Automatic   First Owner    7
# 572       10000  Diesel      Dealer    Automatic   First Owner    7
# 553       10000  Diesel      Dealer    Automatic   First Owner    7
# 1705      35000  Diesel  Individual    Automatic   First Owner   10
# 1088      53000  Diesel      Dealer    Automatic   First Owner    9
# 1479      17000  Diesel      Dealer    Automatic   First Owner    6

# %% [markdown]
# Dataset also has  premium cars
#
# Highest Selling price is  89,00,000

# %%
df[df['km_driven'] > df['km_driven'].quantile(0.99)].sort_values(by="km_driven",ascending=False)
# Out:
#                                                name  selling_price  km_driven  \
# 1243                         Maruti Swift VXI BSIII         250000     806599
# 4184              Maruti SX4 S Cross DDiS 320 Delta         665000     560000
# 525               Maruti SX4 S Cross DDiS 320 Delta         665000     560000
# 3679    Toyota Innova 2.5 G (Diesel) 7 Seater BS IV         400000     400000
# 69    Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII         280000     350000
# 2394            Toyota Innova 2.5 V Diesel 8-seater         350000     350000
# 3718                Toyota Innova 2.5 GX 8 STR BSIV         420000     347089
# 1674           Volkswagen Jetta 2.0 TDI Comfortline         350000     312000
# 1101                                Tata Indica DLS          85000     300000
# 3994                          Tata Indica GLS BS IV          75000     300000
# 3898                          Tata Indica GLS BS IV          90000     300000
# 1659    Toyota Innova 2.5 G (Diesel) 8 Seater BS IV         229999     300000
# 3646    Toyota Innova 2.5 G (Diesel) 8 Seater BS IV         229999     300000
# 2964                               Maruti Swift VDI         225000     296823
# 3675                               Mahindra Xylo E9         300000     295000
# 3979                   Mahindra Verito 1.5 D2 BSIII         150000     280000
# 2961                 Mahindra Scorpio VLS 2.2 mHawk         300000     270000
# 2401         Toyota Innova 2.5 E Diesel MS 7-seater         665000     267000
# 3171                         Maruti Swift Dzire VDI         450000     260000
# 4208                            Toyota Qualis FS B3         150000     256000
# 2402                      Mahindra Scorpio 2.6 CRDe         175000     250000
# 2760               Tata New Safari DICOR 2.2 EX 4x2         300000     250000
# 4088                                  Maruti 800 AC         120000     250000
# 3981         Toyota Innova 2.5 VX (Diesel) 8 Seater        1030000     250000
# 3461  Toyota Innova 2.5 EV Diesel PS 7 Seater BSIII         300000     250000
# 2278                            Hyundai Accent CRDi         170000     245244
# 1668         Toyota Innova 2.5 GX (Diesel) 7 Seater         650000     244000
# 3470         Mahindra Xylo Celebration Edition BSIV         200000     240000
# 3572           Mahindra Scorpio VLX 2WD AIRBAG BSIV         600000     238000
# 3611                           Hyundai Verna 1.6 SX         434999     235000
# 1414            Skoda Superb Elegance 2.0 TDI CR AT         450000     235000
# 1253                    Toyota Corolla Altis D-4D J         715000     234000
# 4231    Toyota Innova 2.5 G (Diesel) 8 Seater BS IV         800000     230000
# 1923                      Mahindra Bolero SLE BSIII         185000     230000
# 197                                Mahindra Xylo E4         229999     230000
# 70                 Toyota Corolla Altis Diesel D4DG         350000     230000
# 3531                        Ford Endeavour 2.5L 4X2         500000     224642
# 1426              Mahindra Scorpio VLX AT 2WD BSIII         225000     223660
# 1116            Toyota Innova 2.5 V Diesel 7-seater         200000     223000
# 2955           Toyota Innova 2.5 G4 Diesel 7-seater         440000     223000
# 3541                      Mahindra Scorpio 2.6 CRDe         180000     222435
# 3734                         Mahindra XUV500 W8 2WD         550000     222252
# 2855                      Mahindra Scorpio 2.6 CRDe         229999     221000
#
#         fuel seller_type transmission                 owner  Age
# 1243  Petrol      Dealer       Manual           First Owner   16
# 4184  Diesel      Dealer       Manual           First Owner    9
# 525   Diesel      Dealer       Manual           First Owner    9
# 3679  Diesel  Individual       Manual           Third Owner   19
# 69    Diesel  Individual       Manual          Second Owner   15
# 2394  Diesel  Individual       Manual           First Owner   16
# 3718  Diesel      Dealer       Manual           First Owner   16
# 1674  Diesel  Individual       Manual           Third Owner   14
# 1101  Diesel  Individual       Manual          Second Owner   19
# 3994  Petrol  Individual       Manual           Third Owner   15
# 3898  Petrol  Individual       Manual           Third Owner   15
# 1659  Diesel  Individual       Manual           First Owner   19
# 3646  Diesel  Individual       Manual           First Owner   19
# 2964  Diesel  Individual       Manual           First Owner   13
# 3675  Diesel  Individual       Manual           First Owner   13
# 3979  Diesel  Individual       Manual           First Owner   14
# 2961  Diesel  Individual       Manual           Third Owner   17
# 2401  Diesel  Individual       Manual          Second Owner   14
# 3171  Diesel  Individual       Manual          Second Owner   11
# 4208  Diesel      Dealer       Manual           First Owner   24
# 2402  Diesel  Individual       Manual          Second Owner   20
# 2760  Diesel  Individual       Manual          Second Owner   15
# 4088  Petrol  Individual       Manual          Second Owner   16
# 3981  Diesel  Individual       Manual          Second Owner   11
# 3461  Diesel  Individual       Manual           First Owner   13
# 2278  Diesel  Individual       Manual  Fourth & Above Owner   19
# 1668  Diesel  Individual       Manual           First Owner   11
# 3470  Diesel  Individual       Manual           Third Owner   15
# 3572  Diesel  Individual       Manual           First Owner   11
# 3611  Diesel  Individual       Manual          Second Owner   13
# 1414  Diesel  Individual    Automatic           First Owner   14
# 1253  Diesel  Individual       Manual           First Owner   11
# 4231  Diesel  Individual       Manual           First Owner   14
# 1923  Diesel  Individual       Manual          Second Owner   18
# 197   Diesel  Individual       Manual           Third Owner   16
# 70    Diesel  Individual       Manual           First Owner   14
# 3531  Diesel      Dealer       Manual          Second Owner   14
# 1426  Diesel  Individual    Automatic           Third Owner   21
# 1116  Diesel  Individual       Manual           First Owner   20
# 2955  Diesel  Individual       Manual  Fourth & Above Owner   18
# 3541  Diesel  Individual       Manual          Second Owner   19
# 3734  Diesel  Individual       Manual           First Owner   12
# 2855  Diesel  Individual       Manual           Third Owner   20

# %% [markdown]
# Highest km_driven is 8,06,599

# %%
df[df['Age'] > df['Age'].quantile(0.99)].sort_values(by="Age",ascending=False)
# Out:
#                                name  selling_price  km_driven    fuel  \
# 3334             Maruti 800 AC BSII          50000     100000  Petrol
# 631        Maruti Gypsy E MG410W ST          95000     100000  Petrol
# 61         Mahindra Jeep CL 500 MDI         250000      35000  Diesel
# 2972           Mahindra Jeep MM 540         200000      60000  Diesel
# 3550               Maruti Esteem AX          79000      70000  Petrol
# 3661                 Maruti 800 Std          50000      80000  Petrol
# 1669       Mahindra Jeep CL 500 MDI         150000     120000  Diesel
# 2044      Mercedes-Benz E-Class 230        1000000      35000  Petrol
# 3371             Honda City 1.3 EXI          85000     120000  Petrol
# 3237                 Maruti 800 Std          40000      40000  Petrol
# 2908                 Maruti 800 Std          55000      80000  Petrol
# 3621                  Maruti Zen LX          42000      70000  Petrol
# 137                  Maruti 800 Std          40000      40000  Petrol
# 2342          Maruti Omni 5 Str STD          65000      60000  Petrol
# 2337      Mercedes-Benz E-Class 230        1000000      35000  Petrol
# 1943                 Maruti Zen LXI          69000      70000  Petrol
# 3532                 Maruti Zen LXI          80000     120000  Petrol
# 3622                  Maruti Zen LX          42000      70000  Petrol
# 1699      Maruti Omni 5 Str STD LPG          50000      35000     LPG
# 2097           Hyundai Accent GLE 1          60000      90000  Petrol
# 1579          Mahindra Jeep Classic         170000       2020  Diesel
# 3849                  Maruti Zen LX          70000      70000  Petrol
# 3856                  Maruti 800 AC          50000     100000  Petrol
# 2777                  Maruti Zen LX          75000      70000  Petrol
# 2904                  Maruti Zen LX          70000      70000  Petrol
# 1126               Maruti Esteem VX          60000      35000  Petrol
# 850                  Maruti Zen LXI          85000      70000  Petrol
# 391   Hyundai Santro GLS I - Euro I          50000     120000  Petrol
# 3396                 Maruti 800 Std          45000      50000  Petrol
# 3889                 Maruti Alto LX          61000      90000  Petrol
# 3984                  Maruti Zen LX          85000      80000  Petrol
# 2495              Ford Ikon 1.4 ZXi          22000      42743  Petrol
# 2635                 Maruti Zen VXI         100000     120000  Petrol
# 2560             Maruti Wagon R VXI         105000      80000  Petrol
# 1927                  Maruti Zen LX          60000      50000  Petrol
# 1598              Maruti Wagon R VX          50000      88500  Petrol
# 1404                  Maruti 800 DX          50000      60000  Petrol
# 1397       Mahindra Jeep MM 775 XDB         155000      50000  Diesel
# 1184     Maruti Gypsy King Hard Top         165000      60000  Petrol
# 372                   Maruti 800 AC          60000      40000  Petrol
# 4325                Maruti Alto LXi          65000      90000  Petrol
#
#      seller_type transmission                 owner  Age
# 3334  Individual       Manual  Fourth & Above Owner   33
# 631   Individual       Manual          Second Owner   30
# 61    Individual       Manual          Second Owner   29
# 2972  Individual       Manual           First Owner   29
# 3550  Individual    Automatic           First Owner   28
# 3661  Individual       Manual          Second Owner   28
# 1669  Individual       Manual           Third Owner   28
# 2044  Individual    Automatic          Second Owner   27
# 3371  Individual       Manual          Second Owner   27
# 3237  Individual       Manual  Fourth & Above Owner   27
# 2908  Individual       Manual  Fourth & Above Owner   27
# 3621  Individual       Manual           Third Owner   27
# 137   Individual       Manual  Fourth & Above Owner   27
# 2342      Dealer       Manual           Third Owner   27
# 2337  Individual    Automatic          Second Owner   27
# 1943  Individual       Manual          Second Owner   27
# 3532  Individual       Manual          Second Owner   27
# 3622  Individual       Manual           Third Owner   27
# 1699  Individual       Manual          Second Owner   27
# 2097  Individual       Manual  Fourth & Above Owner   26
# 1579  Individual       Manual          Second Owner   26
# 3849  Individual       Manual  Fourth & Above Owner   26
# 3856  Individual       Manual          Second Owner   26
# 2777  Individual       Manual           First Owner   26
# 2904  Individual       Manual  Fourth & Above Owner   26
# 1126  Individual       Manual          Second Owner   26
# 850   Individual       Manual          Second Owner   26
# 391   Individual       Manual          Second Owner   26
# 3396  Individual       Manual           Third Owner   26
# 3889  Individual       Manual          Second Owner   25
# 3984  Individual       Manual          Second Owner   25
# 2495      Dealer       Manual           Third Owner   25
# 2635  Individual       Manual           First Owner   25
# 2560  Individual       Manual           First Owner   25
# 1927  Individual       Manual           First Owner   25
# 1598  Individual       Manual  Fourth & Above Owner   25
# 1404  Individual       Manual           First Owner   25
# 1397  Individual       Manual          Second Owner   25
# 1184  Individual       Manual  Fourth & Above Owner   25
# 372   Individual       Manual           Third Owner   25
# 4325  Individual       Manual          Second Owner   25

# %% [markdown]
# Highest age of car is 29 Years

# %%
df.sort_values(by="selling_price")
# Out:
#                                                    name  selling_price  \
# 2662                              Ford Ikon 1.6 ZXI NXt          20000
# 2495                                  Ford Ikon 1.4 ZXi          22000
# 2444                                      Maruti 800 EX          30000
# 3206                                   OpelCorsa 1.4 GL          35000
# 2849                                 Tata Nano Std BSII          35000
# ...                                                 ...            ...
# 1023                            BMW X5 xDrive 30d xLine        4950000
# 2239                            BMW X5 xDrive 30d xLine        4950000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC        5500000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance        8900000
#
#       km_driven    fuel seller_type transmission         owner  Age
# 2662      25000  Petrol  Individual       Manual  Second Owner   20
# 2495      42743  Petrol      Dealer       Manual   Third Owner   25
# 2444      60000  Petrol  Individual       Manual   Third Owner   21
# 3206     100000  Petrol  Individual       Manual   Third Owner   23
# 2849      50000  Petrol  Individual       Manual   Third Owner   16
# ...         ...     ...         ...          ...           ...  ...
# 1023      30000  Diesel      Dealer    Automatic   First Owner    6
# 2239      30000  Diesel      Dealer    Automatic   First Owner    6
# 3969      77350  Diesel      Dealer    Automatic   First Owner    9
# 89         6500  Diesel      Dealer    Automatic   First Owner    8
# 3872      13000  Petrol      Dealer    Automatic   First Owner    9
#
# [4340 rows x 8 columns]

# %%
df["name"].value_counts().sort_values(ascending=False).head(10).iplot(kind="bar")

# %% [markdown]
# Maruti swift Dzire VDI have the highest listing in used cars

# %%
fuel=df.groupby(by="fuel")

# %%
fuel.selling_price.mean().sort_values(ascending=False).iplot(kind="bar")

# %% [markdown]
# Disel Car have highest average selling price

# %%
#sns.heatmap(df.corr(), annot=True, cmap="RdBu")
#plt.show()

# %%
owner=df.groupby(by="owner")

# %%
owner.selling_price.mean().sort_values(ascending=False).iplot(kind="bar")

# %%
sns.pairplot(df)
# Out:
# C:\Users\kaner\anaconda3\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\kaner\anaconda3\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\kaner\anaconda3\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
df.shape
# Out:
# (4340, 8)

# %%
car_names=df["name"].unique()

# %%
df["name"].nunique()
# Out:
# 1491

# %%
pd.DataFrame(car_names)
# Out:
#                                                  0
# 0                                    Maruti 800 AC
# 1                         Maruti Wagon R LXI Minor
# 2                             Hyundai Verna 1.6 SX
# 3                           Datsun RediGO T Option
# 4                            Honda Amaze VX i-DTEC
# ...                                            ...
# 1486                              Maruti Swift LDI
# 1487                                  Tata Nano XM
# 1488                  Mahindra Verito 1.5 D6 BSIII
# 1489  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV
# 1490                    Hyundai i20 Magna 1.4 CRDi
#
# [1491 rows x 1 columns]

# %%
df['brand'] = df['name'].str.split(' ').str[0]

# %%
df
# Out:
#                                      name  selling_price  km_driven    fuel  \
# 0                           Maruti 800 AC          60000      70000  Petrol
# 1                Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2                    Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3                  Datsun RediGO T Option         250000      46000  Petrol
# 4                   Honda Amaze VX i-DTEC         450000     141000  Diesel
# ...                                   ...            ...        ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000  Diesel
# 4337                  Maruti 800 AC BSIII         110000      83000  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000  Diesel
# 4339                     Renault KWID RXT         225000      40000  Petrol
#
#      seller_type transmission         owner  Age    brand
# 0     Individual       Manual   First Owner   18   Maruti
# 1     Individual       Manual   First Owner   18   Maruti
# 2     Individual       Manual   First Owner   13  Hyundai
# 3     Individual       Manual   First Owner    8   Datsun
# 4     Individual       Manual  Second Owner   11    Honda
# ...          ...          ...           ...  ...      ...
# 4335  Individual       Manual  Second Owner   11  Hyundai
# 4336  Individual       Manual  Second Owner   11  Hyundai
# 4337  Individual       Manual  Second Owner   16   Maruti
# 4338  Individual       Manual   First Owner    9  Hyundai
# 4339  Individual       Manual   First Owner    9  Renault
#
# [4340 rows x 9 columns]

# %%
df.brand.unique()
# Out:
# array(['Maruti', 'Hyundai', 'Datsun', 'Honda', 'Tata', 'Chevrolet',
#        'Toyota', 'Jaguar', 'Mercedes-Benz', 'Audi', 'Skoda', 'Jeep',
#        'BMW', 'Mahindra', 'Ford', 'Nissan', 'Renault', 'Fiat',
#        'Volkswagen', 'Volvo', 'Mitsubishi', 'Land', 'Daewoo', 'MG',
#        'Force', 'Isuzu', 'OpelCorsa', 'Ambassador', 'Kia'], dtype=object)

# %%
df.brand.nunique()
# Out:
# 29

# %%
df.brand.value_counts().sort_values(ascending=False).iplot(kind="bar")

# %%
df.brand.value_counts().sort_values().head(15).iplot(kind="bar")

# %%
df[df.selling_price>2500000].sort_values(by="selling_price").brand.unique()
# Out:
# array(['Jaguar', 'Audi', 'Toyota', 'BMW', 'Ford', 'Mahindra', 'Land',
#        'Mercedes-Benz', 'Volvo'], dtype=object)

# %% [markdown]
# # Analysis of premium segment cars

# %%
top_brands=['Jaguar', 'Audi', 'BMW','Land','Mercedes-Benz', 'Volvo']

# %%
df[df["brand"] == 'Audi']
# Out:
#                                           name  selling_price  km_driven  \
# 32                             Audi Q5 2.0 TDI        1190000     175900
# 35             Audi A6 2.0 TDI  Design Edition        1735000      50000
# 44              Audi Q7 35 TDI Quattro Premium        1250000      78000
# 94                Audi A6 2.0 TDI Premium Plus        1470000      34000
# 96                             Audi A8 4.2 TDI        2800000      49000
# 99        Audi A4 2.0 TDI 177 Bhp Premium Plus        1150000      53000
# 431                            Audi Q5 2.0 TDI        1350000      90000
# 554                    Audi A4 3.0 TDI Quattro        1580000      86000
# 566               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 573                    Audi A4 3.0 TDI Quattro        1580000      86000
# 585               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 592                    Audi A4 3.0 TDI Quattro        1580000      86000
# 604               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 611                    Audi A4 3.0 TDI Quattro        1580000      86000
# 623               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 721           Audi A4 New  2.0 TDI Multitronic        1549000      42215
# 899                    Audi A4 3.0 TDI Quattro        1580000      86000
# 911               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 918                    Audi A4 3.0 TDI Quattro        1580000      86000
# 930               Audi A6 2.0 TDI Premium Plus        1300000      58500
# 959          Audi Q3 35 TDI Quattro Technology        2700000      25000
# 963                          Audi A5 Sportback        4700000       1500
# 1033              Audi A6 2.0 TDI Premium Plus        1300000      58500
# 1065                Audi A4 30 TFSI Technology        3100000      22000
# 1077                   Audi A4 3.0 TDI Quattro        1580000      86000
# 1078      Audi Q3 2.0 TDI Quattro Premium Plus        1750000     127643
# 1080           Audi A6 2.0 TDI  Design Edition        1750000     102354
# 1081     Audi Q5 2.0 TFSI Quattro Premium Plus        1850000      62237
# 1410                    Audi A4 35 TDI Premium        2300000      35000
# 1462                 Audi A8 L 3.0 TDI quattro        1250000      47000
# 1479               Audi A4 35 TDI Premium Plus        3256000      17000
# 1705                           Audi Q5 2.0 TDI        3500000      35000
# 1835                   Audi A4 3.0 TDI Quattro        1580000      86000
# 1847              Audi A6 2.0 TDI Premium Plus        1300000      58500
# 2238                   Audi A4 3.0 TDI Quattro        1580000      86000
# 2250              Audi A6 2.0 TDI Premium Plus        1300000      58500
# 2257                   Audi A4 3.0 TDI Quattro        1580000      86000
# 2269              Audi A6 2.0 TDI Premium Plus        1300000      58500
# 2295        Audi Q5 3.0 TDI Quattro Technology        3899000      22000
# 2323                Audi A4 30 TFSI Technology        3100000      22000
# 2572              Audi A6 2.0 TDI Premium Plus        1470000      34000
# 2574                           Audi A8 4.2 TDI        2800000      49000
# 2578      Audi A4 2.0 TDI 177 Bhp Premium Plus        1150000      53000
# 2685                  Audi Q5 2.0 TFSI Quattro        1100000     110000
# 2738                   Audi A4 3.0 TDI Quattro        1580000      86000
# 2750              Audi A6 2.0 TDI Premium Plus        1300000      58500
# 2813      Audi Q3 2.0 TDI Quattro Premium Plus        1150000     110000
# 3082                           Audi A6 2.7 TDI         850000      46000
# 3094                           Audi A4 2.0 TDI        1295000      58000
# 3458                          Audi A4 1.8 TFSI        1200000      60000
# 3783                           Audi A6 2.8 FSI         650000      70000
# 3842                   Audi A4 3.0 TDI Quattro        1580000      86000
# 3843      Audi Q3 2.0 TDI Quattro Premium Plus        1750000     127643
# 3848           Audi A6 2.0 TDI  Design Edition        1750000     102354
# 3851         Audi Q3 35 TDI Quattro Technology        2575000      36000
# 3854     Audi Q5 2.0 TFSI Quattro Premium Plus        1850000      62237
# 3872  Audi RS7 2015-2019 Sportback Performance        8900000      13000
# 3873        Audi Q5 3.0 TDI Quattro Technology        3200000      30000
# 4163      Audi Q3 2.0 TDI Quattro Premium Plus        1400000     118000
# 4304        Audi Q5 3.0 TDI Quattro Technology        3899000      22000
#
#         fuel seller_type transmission         owner  Age brand
# 32    Diesel      Dealer    Automatic   First Owner   14  Audi
# 35    Diesel      Dealer    Automatic   First Owner   12  Audi
# 44    Diesel      Dealer    Automatic   Third Owner   16  Audi
# 94    Diesel      Dealer    Automatic  Second Owner   11  Audi
# 96    Diesel      Dealer    Automatic   First Owner   12  Audi
# 99    Diesel      Dealer    Automatic   First Owner   12  Audi
# 431   Diesel  Individual    Automatic  Second Owner   13  Audi
# 554   Diesel      Dealer    Automatic   First Owner   12  Audi
# 566   Diesel      Dealer    Automatic   First Owner   12  Audi
# 573   Diesel      Dealer    Automatic   First Owner   12  Audi
# 585   Diesel      Dealer    Automatic   First Owner   12  Audi
# 592   Diesel      Dealer    Automatic   First Owner   12  Audi
# 604   Diesel      Dealer    Automatic   First Owner   12  Audi
# 611   Diesel      Dealer    Automatic   First Owner   12  Audi
# 623   Diesel      Dealer    Automatic   First Owner   12  Audi
# 721   Diesel      Dealer    Automatic   First Owner   11  Audi
# 899   Diesel      Dealer    Automatic   First Owner   12  Audi
# 911   Diesel      Dealer    Automatic   First Owner   12  Audi
# 918   Diesel      Dealer    Automatic   First Owner   12  Audi
# 930   Diesel      Dealer    Automatic   First Owner   12  Audi
# 959   Diesel  Individual    Automatic   First Owner    7  Audi
# 963   Diesel  Individual    Automatic   First Owner    5  Audi
# 1033  Diesel      Dealer    Automatic   First Owner   12  Audi
# 1065  Petrol  Individual    Automatic   First Owner    7  Audi
# 1077  Diesel      Dealer    Automatic   First Owner   12  Audi
# 1078  Diesel      Dealer    Automatic   First Owner   10  Audi
# 1080  Diesel      Dealer    Automatic   First Owner   11  Audi
# 1081  Petrol      Dealer    Automatic   First Owner   11  Audi
# 1410  Diesel  Individual    Automatic   Third Owner   10  Audi
# 1462  Diesel      Dealer    Automatic  Second Owner   16  Audi
# 1479  Diesel      Dealer    Automatic   First Owner    6  Audi
# 1705  Diesel  Individual    Automatic   First Owner   10  Audi
# 1835  Diesel      Dealer    Automatic   First Owner   12  Audi
# 1847  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2238  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2250  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2257  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2269  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2295  Diesel      Dealer    Automatic   First Owner    7  Audi
# 2323  Petrol  Individual    Automatic   First Owner    7  Audi
# 2572  Diesel      Dealer    Automatic  Second Owner   11  Audi
# 2574  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2578  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2685  Petrol  Individual    Automatic   First Owner   15  Audi
# 2738  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2750  Diesel      Dealer    Automatic   First Owner   12  Audi
# 2813  Diesel  Individual    Automatic  Second Owner   11  Audi
# 3082  Diesel  Individual    Automatic   First Owner   15  Audi
# 3094  Diesel      Dealer    Automatic   First Owner   14  Audi
# 3458  Petrol  Individual    Automatic   Third Owner   13  Audi
# 3783  Petrol  Individual    Automatic   Third Owner   17  Audi
# 3842  Diesel      Dealer    Automatic   First Owner   12  Audi
# 3843  Diesel      Dealer    Automatic   First Owner   10  Audi
# 3848  Diesel      Dealer    Automatic   First Owner   11  Audi
# 3851  Diesel      Dealer    Automatic   First Owner    8  Audi
# 3854  Petrol      Dealer    Automatic   First Owner   11  Audi
# 3872  Petrol      Dealer    Automatic   First Owner    9  Audi
# 3873  Diesel      Dealer    Automatic   First Owner   10  Audi
# 4163  Diesel  Individual    Automatic  Second Owner   13  Audi
# 4304  Diesel      Dealer    Automatic   First Owner    7  Audi

# %%
tdf=df.loc[df['brand'].isin(top_brands)]

# %%
tdf.shape
# Out:
# (149, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   selling_price  4340 non-null   int64
#  2   km_driven      4340 non-null   int64
#  3   fuel           4340 non-null   object
#  4   seller_type    4340 non-null   object
#  5   transmission   4340 non-null   object
#  6   owner          4340 non-null   object
#  7   Age            4340 non-null   int64
#  8   brand          4340 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 305.3+ KB

# %%
sns.relplot(x=df.selling_price,y=df.km_driven,hue=df.brand)

# %%
sns.relplot(x=tdf.selling_price,y=tdf.km_driven,hue=tdf.brand)

# %%
tdf.brand.value_counts().sort_values(ascending=False).iplot(kind="bar")

# %% [markdown]
# Audi BMW & Mercedes-Benz listing are higher in premium cars.

# %%
topcars=tdf.groupby("brand")

# %%
#topcars.mean().sort_values(by="selling_price").iplot(kind="bar")

# %% [markdown]
# Averge selling price of audi is lowest compared other premium car

# %%
#topcars.mean().sort_values(by="selling_price").sort_values(by="selling_price")

# %%
tdf.transmission.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
tdf.fuel.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# most of  cars are diesel in premium cars

# %%
tdf.seller_type.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Majority of premium cars are sold by Dealers

# %%
tdf.name.value_counts().sort_values(ascending=False).head()
# Out:
# name
# Audi A6 2.0 TDI Premium Plus                13
# Audi A4 3.0 TDI Quattro                     12
# Mercedes-Benz C-Class Progressive C 220d    11
# BMW X5 xDrive 30d xLine                     11
# BMW X1 sDrive 20d xLine                      5
# Name: count, dtype: int64

# %% [markdown]
# This  cars have maximum number of listing in premium car segment.

# %% [markdown]
# # Analysis of Normal Segment cars

# %%
ndf=df.loc[~df['brand'].isin(top_brands)]

# %%
ndf
# Out:
#                                      name  selling_price  km_driven    fuel  \
# 0                           Maruti 800 AC          60000      70000  Petrol
# 1                Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2                    Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3                  Datsun RediGO T Option         250000      46000  Petrol
# 4                   Honda Amaze VX i-DTEC         450000     141000  Diesel
# ...                                   ...            ...        ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000  Diesel
# 4337                  Maruti 800 AC BSIII         110000      83000  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000  Diesel
# 4339                     Renault KWID RXT         225000      40000  Petrol
#
#      seller_type transmission         owner  Age    brand
# 0     Individual       Manual   First Owner   18   Maruti
# 1     Individual       Manual   First Owner   18   Maruti
# 2     Individual       Manual   First Owner   13  Hyundai
# 3     Individual       Manual   First Owner    8   Datsun
# 4     Individual       Manual  Second Owner   11    Honda
# ...          ...          ...           ...  ...      ...
# 4335  Individual       Manual  Second Owner   11  Hyundai
# 4336  Individual       Manual  Second Owner   11  Hyundai
# 4337  Individual       Manual  Second Owner   16   Maruti
# 4338  Individual       Manual   First Owner    9  Hyundai
# 4339  Individual       Manual   First Owner    9  Renault
#
# [4191 rows x 9 columns]

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4191 entries, 0 to 4339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4191 non-null   object
#  1   selling_price  4191 non-null   int64
#  2   km_driven      4191 non-null   int64
#  3   fuel           4191 non-null   object
#  4   seller_type    4191 non-null   object
#  5   transmission   4191 non-null   object
#  6   owner          4191 non-null   object
#  7   Age            4191 non-null   int64
#  8   brand          4191 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 327.4+ KB

# %%
print("Share of Normal Segment Cars in %: ") 
print(len(ndf)/len(df)*100)
print("-------------------------------------")
print("Share of premium Segment Cars in % : ") 
print(len(tdf)/len(df)*100)
# Out:
# Share of Normal Segment Cars in %:
# 96.5668202764977
# -------------------------------------
# Share of premium Segment Cars in % :
# 3.433179723502304

# %%
sns.relplot(x=ndf.selling_price,y=ndf.km_driven,hue=ndf.brand)

# %%
ndf.brand.value_counts().sort_values(ascending=False).iplot(kind="bar")

# %% [markdown]
# Maruti & Hyundai are most popular brands in Normal Car Segment

# %%
normalcars=ndf.groupby("brand")

# %%
#normalcars.mean().sort_values(by="selling_price",ascending=False).iplot(kind="bar")

# %%
#normalcars.mean().sort_values(by="selling_price").sort_values(by="selling_price")

# %%
ndf.transmission.value_counts()
# Out:
# transmission
# Manual       3890
# Automatic     301
# Name: count, dtype: int64

# %%
ndf.seller_type.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
ndf.fuel.value_counts()
# Out:
# fuel
# Petrol      2104
# Diesel      2023
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
ndf.fuel.value_counts().plot.pie(fontsize = 10, autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
ndf.fuel.value_counts().plot.bar()
# Out:
# <Axes: xlabel='fuel'>
